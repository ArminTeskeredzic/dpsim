# %% [markdown]
# # EMT Simulation of topology with slack, line and VSI

# %%
from villas.dataprocessing.readtools import *
from villas.dataprocessing.timeseries import *
import matplotlib.pyplot as plt
import re
import numpy as np
#import dpsimpy

# %matplotlib widget

# %% [markdown]
# ## EMT Simulation

# %% [markdown]
# ### Parametrization

# %%
final_time = 1
time_step = 0.1e-3
sim_name = "scenario_C_step_A"
pv_with_control = True
cmd_scale_P = 1.0
cmd_scale_I = 1.0
V_nom = 20e3

# %% [markdown]
# ### Powerflow for Initialization

# %% [markdown]
# ### Dynamic Simulation

# %% [markdown]
# ## PF results

# %%
modelName = 'scenario_C_step_A_PF'
#path = 'logs/' + modelName + '/'scenario_B_step_A_PF
path = '/home/ate/github/dpsim/build/dpsim/examples/cxx/logs/' + modelName + '/'
dpsim_result_file = path + modelName + '.csv'

ts_dpsim_pf = read_timeseries_csv(dpsim_result_file)
# Out:
# column number: 2
# results length: 3
# real column names: []
# complex column names: ['V_BUS_b_PF', 'V_BUS_gas_PF']

# %% [markdown]
# ## EMT results

# %%
modelName = 'scenario_C_step_A_EMT'
path = '/home/ate/github/dpsim/build/dpsim/examples/cxx/logs/' + modelName + '/'
dpsim_result_file = path + modelName + '.csv'
PEAK1PH_TO_RMS3PH = np.sqrt(3.0/2.0)
ts_dpsim = read_timeseries_csv(dpsim_result_file)
# Out:
# column number: 6
# results length: 701
# real column names: ['BUS_b_EMT_v_0', 'BUS_b_EMT_v_1', 'BUS_b_EMT_v_2', 'BUS_gas_EMT_v_0', 'BUS_gas_EMT_v_1', 'BUS_gas_EMT_v_2']
# complex column names: []

# %%
plt.figure(figsize=(12,6))
for ts_name, ts_obj  in ts_dpsim.items():
        #print(ts_name)
        if ts_name in ['BUS_b_EMT_v_0','a','a','v2_0','v2_1','v2_2']:
                plt.plot(ts_obj.time, PEAK1PH_TO_RMS3PH*ts_obj.values, label=ts_name)
for ts_name, ts_obj  in ts_dpsim_pf.items():
        print(ts_name)
        #plt.plot(ts_obj.time, ts_obj.abs().values, label=ts_name+'_pf', linestyle=':')
plt.legend()
plt.show()
# Out:
# V_BUS_b_PF
# V_BUS_gas_PF

# %%
plt.figure(figsize=(12,6))
for ts_name, ts_obj  in ts_dpsim.items():
    #print(ts_name)
    if ts_name in ['BUS_a_EMT_v_0','i12_1','i12_2']:
        plt.plot(ts_obj.time, PEAK1PH_TO_RMS3PH*ts_obj.values, label=ts_name)

plt.legend()
plt.show()
# Out:
# BUS_a_EMT_v_0
# BUS_a_EMT_v_1
# BUS_a_EMT_v_2
# BUS_b_EMT_b_0
# BUS_b_EMT_b_1
# BUS_b_EMT_b_2
# BUS_gas_EMT_v_0
# BUS_gas_EMT_v_1
# BUS_gas_EMT_v_2
# GEN_gas_EMT_delta
# GEN_gas_EMT_ep_mag
# GEN_gas_EMT_i
# GEN_gas_EMT_v
# GEN_gas_EMT_wr
# P_elec1
# P_mech1
# cable_EMT_i_0
# cable_EMT_i_1
# cable_EMT_i_2
# cable_EMT_v_0
# cable_EMT_v_1
# cable_EMT_v_2
# line3_EMT_i_0
# line3_EMT_i_1
# line3_EMT_i_2
# line3_EMT_v_0
# line3_EMT_v_1
# line3_EMT_v_2
# load_bus_a_EMT_i_0
# load_bus_a_EMT_i_1
# load_bus_a_EMT_i_2
# load_bus_a_EMT_v_0
# load_bus_a_EMT_v_1
# load_bus_a_EMT_v_2
# load_bus_b_EMT_i_0
# load_bus_b_EMT_i_1
# load_bus_b_EMT_i_2
# load_bus_b_EMT_v_0
# load_bus_b_EMT_v_1
# load_bus_b_EMT_v_2

# %%
plt.figure(figsize=(12,6))
for ts_name, ts_obj  in ts_dpsim.items():
    if ts_name in ['pv_v_intf_0']:
        plt.plot(ts_obj.time, PEAK1PH_TO_RMS3PH*ts_obj.values, label=ts_name)

plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_476623/1275644989.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(12,6))
for ts_name, ts_obj  in ts_dpsim.items():
    if ts_name in ['pv_i_intf_0']:
        plt.plot(ts_obj.time, PEAK1PH_TO_RMS3PH*ts_obj.values, label=ts_name)

plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_476623/2858890797.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
